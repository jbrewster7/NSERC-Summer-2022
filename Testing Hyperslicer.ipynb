# %%
# %pylab ipympl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from topas2numpy import BinnedResult

# %%
import mpl_interactions.ipyplot as iplt
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, np.pi, 100)
tau = np.linspace(0.5, 10, 100)

def f1(x, tau, beta):
    return np.sin(x * tau) * x * beta
def f2(x, tau, beta):
    return np.sin(x * beta) * x * tau


fig, ax = plt.subplots()
controls = iplt.plot(x, f1, tau=tau, beta=(1, 10, 100), label="f1")
iplt.plot(x, f2, controls=controls, label="f2")
plt.legend()
plt.show()

iplt.plot?
# Out:
# VBox(children=(HBox(children=(IntSlider(value=0, description='tau', max=99, readout=False), Label(value='0.50'…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import io

import matplotlib.pyplot as plt
import numpy as np
import requests

from mpl_interactions import hyperslicer

# %%
data2 = BinnedResult('WaterKernel.csv').data['Sum']

# %%
print(np.max(data))
# Out:
# 20.08016777038574

# %%
fig1, ax1 = plt.subplots()
control1 = hyperslicer(data, vmin=0, vmax=np.max(data), play_buttons=True, play_button_pos="left")
# Out:
# VBox(children=(HBox(children=(Play(value=0, max=99), IntSlider(value=0, description='axis0', max=99, readout=F…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data2 = BinnedResult('KernelScorer.csv').data['Sum']

# %%
fig1, ax1 = plt.subplots()
control1 = hyperslicer(data2, vmin=0, vmax=np.max(data2), play_buttons=True, play_button_pos="left")
# Out:
# VBox(children=(HBox(children=(Play(value=0, max=7), IntSlider(value=0, description='axis0', max=7, readout=Fal…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
