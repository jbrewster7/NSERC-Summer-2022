# %%
# %pylab ipympl
import skimage.data
import scipy.ndimage
import scipy.ndimage.filters

from scipy import signal

img = skimage.data.astronaut()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ifig=1;close(ifig);figure(ifig)

imshow(img)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
identity = array([[0,0,0],[0,1,0],[0,0,0]])
ridge = array([[-1,-1,-1],[-1,4,-1],[-1,-1,-1]])
test = array([[-1,-1,-1],[-1,4,-1],[-1,3,2]])

# %%
def swap(mat):
    '''
    '''
    newmat = []
    inmat = []
    for row in mat:
        newrow = []
        for ind in range(len(row),0,-1):
            newrow.append(row[ind-1])
        inmat.append(newrow)
    
    for rowind in range(len(inmat),0,-1):
        newmat.append(inmat[rowind-1])
    
    print(newmat)

# %%
def con(kernel,im):
    '''
    '''
    op = swap(kernal)

# %%
shape(img)
# Out:
# (512, 512, 3)
